# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshudhyani/Colab_learning_project/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Test_data.csv')
df.head()
# Out:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     2           3   Female         50         157          50
# 2     3           6   Female         47         150          47
# 3     4           8     Male         45         172          65
# 4     5           9   Female         46         155          65
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            160                              93
# 2                            101                              71
# 3                            136                              93
# 4                            123                              73
#
#    Heart Rate(b/m)  BMI(kg/m^2)          Hypertension Diabetes  \
# 0               97        27.27  Stage 2 hypertension      NaN
# ...

# %%
df.notnull()
# Out:
#      Num.  subject_ID  Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0    True        True      True       True        True        True
# 1    True        True      True       True        True        True
# 2    True        True      True       True        True        True
# 3    True        True      True       True        True        True
# 4    True        True      True       True        True        True
# ..    ...         ...       ...        ...         ...         ...
# 214  True        True      True       True        True        True
# 215  True        True      True       True        True        True
# 216  True        True      True       True        True        True
# 217  True        True      True       True        True        True
# 218  True        True      True       True        True        True
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                             True                            True
# ...

# %%
healthy = df[df['Hypertension'] == 'Normal']
healthy
# Out:
#      Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 2       3           6   Female         47         150          47
# 7       8          12   Female         53         160          70
# 8       9          13     Male         58         165          55
# 9      10          14   Female         47         150          47
# 12     13          17   Female         48         155          57
# ..    ...         ...      ...        ...         ...         ...
# 213   214         414   Female         24         168          55
# 214   215         415     Male         24         180          70
# 215   216         416   Female         25         156          47
# 217   218         418     Male         25         173          63
# 218   219         419     Male         24         175          58
#
#      Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 2                              101                              71
# ...

# %%
healthy.to_csv('healthy.csv')

# %%
extreme = df[df['Hypertension'] == 'Stage 2 hypertension']

# %%
extreme.to_csv('extreme.csv')

# %%
plt.plot(range(20), healthy[:20]['Systolic Blood Pressure(mmHg)'], label="Healthy Systolic BP", color='blue')
plt.plot(range(20), extreme[:20]['Systolic Blood Pressure(mmHg)'], label="Extreme Systolic BP", color='red')

plt.plot(range(20), healthy[:20]['Diastolic Blood Pressure(mmHg)'], label="Healthy Diastolic BP", color='cyan')

plt.plot(range(20), extreme[:20]['Diastolic Blood Pressure(mmHg)'], label="Extreme Diastolic BP", color='orange')

plt.title("Blood Pressure Comparison")
plt.xlabel("Index")

plt.ylabel("Blood Pressure (mmHg)")
plt.legend()

# %%
healthy.describe()
# Out:
#              Num.  subject_ID  Age(year)  Height(cm)  Weight(kg)  \
# count   80.000000   80.000000  80.000000   80.000000   80.000000
# mean   112.787500  175.075000  49.425000  161.537500   57.825000
# std     70.344666  132.189524  17.174293    8.037796   10.886962
# min      3.000000    6.000000  21.000000  150.000000   38.000000
# 25%     47.750000   62.750000  31.500000  155.000000   50.000000
# 50%    113.000000  155.000000  53.000000  160.000000   55.500000
# 75%    180.250000  231.250000  62.000000  168.000000   63.250000
# max    219.000000  419.000000  85.000000  183.000000   89.000000
#
#        Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# count                      80.000000                       80.000000
# mean                      107.800000                       64.062500
# std                         8.922167                        6.903207
# min                        80.000000                       42.000000
# ...

# %%
extreme.describe()
# Out:
#              Num.  subject_ID  Age(year)  Height(cm)  Weight(kg)  \
# count   20.000000   20.000000  20.000000   20.000000   20.000000
# mean    66.700000   92.000000  63.850000  160.550000   62.100000
# std     52.558839   69.100232  11.784356    6.816968   13.146542
# min      1.000000    2.000000  45.000000  150.000000   40.000000
# 25%     24.750000   30.750000  53.500000  155.000000   53.750000
# 50%     56.500000   86.500000  66.000000  161.000000   63.500000
# 75%     89.750000  127.500000  74.750000  165.000000   70.000000
# max    177.000000  228.000000  80.000000  170.000000   90.000000
#
#        Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# count                      20.000000                       20.000000
# mean                      168.700000                       87.200000
# std                         7.441703                       11.241839
# min                       160.000000                       63.000000
# ...

# %%
SBP = healthy['Systolic Blood Pressure(mmHg)'] - extreme['Systolic Blood Pressure(mmHg)']
DBP = healthy['Diastolic Blood Pressure(mmHg)'] - extreme['Diastolic Blood Pressure(mmHg)']

SBP
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 7     NaN
# 8     NaN
#        ..
# 213   NaN
# 214   NaN
# 215   NaN
# 217   NaN
# 218   NaN
# Name: Systolic Blood Pressure(mmHg), Length: 100, dtype: float64

# %%
healthy['MAP'] = (healthy['Systolic Blood Pressure(mmHg)'] + 2*healthy['Diastolic Blood Pressure(mmHg)'])/3
healthy.head()
# Out:
# <ipython-input-37-778c67d78540>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   healthy['MAP'] = (healthy['Systolic Blood Pressure(mmHg)'] + 2*healthy['Diastolic Blood Pressure(mmHg)'])/3
#     Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 2      3           6   Female         47         150          47
# 7      8          12   Female         53         160          70
# 8      9          13     Male         58         165          55
# 9     10          14   Female         47         150          47
# 12    13          17   Female         48         155          57
#
#     Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 2                             101                              71
# ...

# %%
plt.scatter(healthy['Heart Rate(b/m)'], healthy['MAP'])
plt.plot(range(50, 100), range(50, 100), color = 'black')

# %%
with open("2_1.txt", 'r') as file:
    line = file.read().strip()

data1 = list(map(float, line.split('\t')))
plt.plot(data1, label='Data Values')

# %%
with open("2_2.txt", 'r') as file:
    line = file.read().strip()

data2 = list(map(float, line.split('\t')))
plt.plot(data2, label='Data Values')

# %%
with open("2_2.txt", 'r') as file:
    line = file.read().strip()

data3 = list(map(float, line.split('\t')))
plt.plot(data3, label='Data Values')

# %%
plt.plot(data1, label='Data 1', color = 'red')
plt.plot(data2, label='Data 2', color = 'blue')
plt.plot(data3, label='Data 3', color = 'green')
